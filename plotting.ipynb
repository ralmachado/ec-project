# %%
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

tsp = Path.cwd() / "tsp"
rastrigin = Path.cwd() / "rastrigin"
schwefel = Path.cwd() / "schwefel"
quartic = Path.cwd() / "quartic"

# %%
for file in sorted(Path(schwefel, 'gauss').glob('*_best.txt')):
    plt.plot(np.genfromtxt(file)[1400:], label=file.name)
plt.xlabel("Generation")
plt.ylabel("Fitness")
plt.legend()
plt.show()
